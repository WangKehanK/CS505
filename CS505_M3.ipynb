# %% [markdown]
# <a href="https://colab.research.google.com/github/WangKehanK/CS505/blob/main/CS505_M3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/Twitter_users_labeled_with_age_and_gender.csv", encoding = "latin-1")

# %%
del df["Unnamed: 0"]

# %%
df.head(20)
# Out:
#         screen_name       user_id  ... human.labeled.gender human.labeled.age
# 0     _____zac_____  4.614412e+08  ...                  NaN              23.0
# 1          ___aleia  7.650000e+17  ...                  NaN              19.0
# 2           ___Dals  4.361882e+08  ...                    F               NaN
# 3   ___schaeffer___  1.257110e+09  ...                  NaN              22.0
# 4    __andresiscool  1.030000e+18  ...                    M               NaN
# 5   __blowCeeKisses  9.795642e+07  ...                    F               NaN
# 6           __Bone2  2.276869e+09  ...                    M               NaN
# 7         __dennisa  3.004387e+09  ...                    F               NaN
# 8           __drewc  1.050000e+18  ...                  NaN              26.0
# 9     __EmilyRice__  3.797155e+09  ...                  NaN              20.0
# 10      __ginaaaa__  1.941566e+09  ...                  NaN              22.0
# ...

# %%
df['human.labeled.gender'].value_counts()/np.float(len(df))
# Out:
# F    0.361585
# M    0.292073
# Name: human.labeled.gender, dtype: float64

# %%
df['human.labeled.age'].value_counts()/np.float(len(df))
# Out:
# 21.0    0.077439
# 20.0    0.067378
# 22.0    0.066159
# 19.0    0.044207
# 23.0    0.041768
# 18.0    0.030183
# 24.0    0.023780
# 25.0    0.016159
# 26.0    0.011280
# 17.0    0.009146
# 27.0    0.008232
# 28.0    0.005183
# 29.0    0.003963
# 16.0    0.003659
# 30.0    0.002744
# 36.0    0.002134
# 38.0    0.001524
# 40.0    0.001220
# 55.0    0.001220
# 34.0    0.001220
# 46.0    0.000915
# 32.0    0.000915
# 15.0    0.000915
# 33.0    0.000915
# 41.0    0.000915
# 43.0    0.000915
# 39.0    0.000915
# 31.0    0.000610
# 49.0    0.000610
# 35.0    0.000610
# 37.0    0.000610
# 67.0    0.000610
# 42.0    0.000610
# 14.0    0.000610
# 64.0    0.000305
# 51.0    0.000305
# 45.0    0.000305
# 70.0    0.000305
# 58.0    0.000305
# 68.0    0.000305
# 13.0    0.000305
# 47.0    0.000305
# 48.0    0.000305
# 53.0    0.000305
# 44.0    0.000305
# 65.0    0.000305
# 50.0    0.000305
# 56.0    0.000305
# 52.0    0.000305
# Name: human.labeled.age, dtype: float64

# %%
df['profile_image_url'].tolist()
# Out:
# ['http://pbs.twimg.com/profile_images/1226134911192633345/CLfdUTPp_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1271280679532331008/TuPDIo73_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1267852466160312322/7qOmBFm2_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1268044218007601152/tXkAfK8T_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1272229718104760321/_gMFE1gg_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1274226895148679168/xHKeAzdL_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1267585783168458752/7IIPgf4d_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1243741019105038339/EYwiK38Z_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1090809548611440640/30-D8wHk_normal.jpg',
#  'http://pbs.twimg.com/profile_images/841520110351319040/tv5RgMxo_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1271606825058795523/cRk-hQVQ_normal.jpg',
#  'http://pbs.twimg.com/profile_images/1272583756990287872/-xTEMn9U_normal.jpg',
# ...
